# %%
import numpy as np
from numpy import linspace
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D
from scipy import signal
from mpl_toolkits.basemap import Basemap

# %%
plt.figure(figsize=(5,5))
m=Basemap(projection='ortho',resolution=None,lat_0=20.5937,lon_0=78.9629)
m.bluemarble(scale=0.5)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.figure(figsize=(5,5))
m=Basemap(projection='merc',resolution=None,lat_0=20.5937,lon_0=78.9629)
m.bluemarble(scale=0.5)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.figure(figsize=(5,5))
m=Basemap(projection='lcc',resolution='c',width=8E6,height=8E6,lat_0=21.2947,lon_0=75.2649)
m.etopo(scale=0.5,alpha=0.5)

x,y=m(80,22)
plt.plot(x,y,'ok',markersize=5)
plt.text(x,y,' India',fontsize=12)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(4488143.532018042, 4085753.623282499, ' India')

# %%
plt.figure(figsize=(5,5))
m=Basemap(projection='robin',resolution=None,lat_0=20.5937,lon_0=78.9629)
m.bluemarble(scale=0.5)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
fig = plt.figure(figsize = (12,12))
m= Basemap()
m.drawcoastlines(linewidth=1.0,linestyle='dashed',color='red')
plt.title("Coastlines",fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize = (12,12))
m= Basemap()
m.drawcountries(linewidth=1.0,linestyle='solid',color='k')
plt.title("Countaries",fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize = (12,12))
m= Basemap(lat_0=20.5937,lon_0=78.9629)
m.drawcoastlines(linewidth=1.0,linestyle='dashed',color='red')
m.drawcountries(linewidth=1.0,linestyle='solid',color='k')
plt.title("Coastlines and Countries",fontsize=20)
x,y=m(80,22)
plt.plot(x,y,'ok',markersize=5)
plt.text(x,y,' India',fontsize=12)
plt.show()

# %%
fig = plt.figure(figsize = (12,12))
m= Basemap(lat_0=20.5937,lon_0=78.9629)
m.drawcoastlines(linewidth=1.0,linestyle='dashed',color='red')
m.drawcountries(linewidth=1.0,linestyle='solid',color='k')
m.drawrivers(linewidth=1.0,linestyle='solid',color='#0000ff')
plt.title("Coastlines Countaries Rivers",fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize = (12,12))
m= Basemap(lat_0=20.5937,lon_0=78.9629)
m.drawcoastlines(linewidth=1.0,linestyle='dashed',color='red')
m.drawcountries(linewidth=1.0,linestyle='solid',color='k')
m.fillcontinents(color='coral',lake_color='aqua')
m.drawmeridians(range(0,360,20),color='k',linewidth=1.0,dashes=[4,4],labels=[0,0,1,1])
plt.title("Longitude Lines",fontsize=20,pad=30)
plt.show()

# %%
fig = plt.figure(figsize = (12,12))
m= Basemap(lat_0=20.5937,lon_0=78.9629)
m.drawcoastlines(linewidth=1.0,linestyle='dashed',color='red')
m.drawcountries(linewidth=1.0,linestyle='solid',color='k')
m.fillcontinents(color='coral',lake_color='aqua')
# m.drawmeridians(range(0,360,20),color='k',linewidth=1.0,dashes=[4,4],labels=[0,0,1,1])
m.drawparallels(range(-90,150,10),color='k',linewidth=1.0,dashes=[4,4],labels=[1,0,0,0])
plt.title("Longitude Lines",fontsize=20,pad=30)
plt.show()

# %%
fig = plt.figure(figsize = (12,12))
m= Basemap(projection='ortho',lat_0=45,lon_0=-100,resolution='l')
m.drawcoastlines(linewidth=1.0,linestyle='dashed',color='red')
m.drawcountries(linewidth=1.0,linestyle='solid',color='k')
m.fillcontinents(color='coral',lake_color='aqua')
# m.drawmeridians(range(0,360,20),color='k',linewidth=1.0,dashes=[4,4],labels=[0,0,1,1])
m.drawparallels(range(-90,100,20),color='k',linewidth=1.0,dashes=[4,4],labels=[1,0,0,0])
plt.title("Contour lines over filled continent background",fontsize=20,pad=30)
m.drawmapboundary(fill_color='aqua')
# draw lat/lon grid lines every 30 degrees.
m.drawmeridians(np.arange(0,360,30))
m.drawparallels(np.arange(-90,90,30))
# make up some data on a regular lat/lon grid.
nlats = 73; nlons = 145; delta = 2.*np.pi/(nlons-1)
lats = (0.5*np.pi-delta*np.indices((nlats,nlons))[0,:,:])
lons = (delta*np.indices((nlats,nlons))[1,:,:])
wave = 0.75*(np.sin(2.*lats)**8*np.cos(4.*lons))
mean = 0.5*np.cos(2.*lats)*((np.sin(2.*lats))**2 + 2.)
# compute native map projection coordinates of lat/lon grid.
x, y = m(lons*180./np.pi, lats*180./np.pi)
# contour data over the map.
cs = m.contour(x,y,wave+mean,15,linewidths=1.5)
plt.show()

# %% [markdown]
# 1. Locate Karnataka
# 2. Plot bangalore
# 3. Apply all the function

# %%
plt.figure(figsize=(5,5))
m=Basemap(projection='lcc',resolution='c',width=8E6,height=8E6,lat_0=15.3173,lon_0=75.7139)
m.etopo(scale=0.5,alpha=0.5)

x,y=m(77.5946,12.9716)
plt.plot(x,y,'ok',markersize=5)
plt.text(x,y,' Bangalore',fontsize=12)
# Out:
# Text(4203955.36669845, 3739981.750897015, ' Bangalore')

# %%
plt.figure(figsize=(5,5))
m=Basemap(projection='lcc',width=8E6,height=8E6,resolution=None,lat_0=15,lon_0=75,area_thresh=1000.0,llcrnrlat=11.0,llcrnrlon=72.0,urcrnrlat=18.5,urcrnrlon=78.5)
# m.drawcounties()
# m.drawstates()
# m.fillcontinents(color='lightgray',lake_color='aqua')
m.bluemarble(scale=0.5)
x,y=m(77.5946,12.9716)
plt.plot(x,y,'ok',markersize=5)
plt.text(x,y,' Bangalore',fontsize=12)
# Out:
# Text(609553.6068618069, 218969.29080426172, ' Bangalore')

# %%
plt.figure(figsize=(5,5))
m=Basemap(projection='lcc',resolution='l',width=1200000,height=900000,lat_0=15,lon_0=75,area_thresh=1000.0,llcrnrlat=11.0,llcrnrlon=72.0,urcrnrlat=18.5,urcrnrlon=78.5)
# m.etopo(scale=0.5,alpha=0.5)
m.drawcoastlines()
m.drawcounties()
m.drawrivers()
m.drawstates()
m.fillcontinents(color='lightgray',lake_color='aqua')
m.drawmapboundary(fill_color='aqua')
x,y=m(77.5946,12.9716)
plt.plot(x,y,'ok',markersize=5)
plt.text(x,y,' Bangalore',fontsize=12)
# Out:
# Text(609553.6068618069, 218969.29080426172, ' Bangalore')
