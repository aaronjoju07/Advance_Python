# %%
import matplotlib
import pandas as pd
import contextily as ctx
import geopandas as gpd

# %%
world_gfd = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
world_gfd
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21476\2751434307.py:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_gfd = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
#          pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       889953.0        Oceania                      Fiji    FJI        5496
# 1     58005463.0         Africa                  Tanzania    TZA       63177
# 2       603253.0         Africa                 W. Sahara    ESH         907
# 3     37589262.0  North America                    Canada    CAN     1736425
# 4    328239523.0  North America  United States of America    USA    21433226
# ..           ...            ...                       ...    ...         ...
# 172    6944975.0         Europe                    Serbia    SRB       51475
# ...

# %%
world_gfd.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
world_gfd['pop_density']= world_gfd.pop_est / world_gfd.area * 10**6
world_gfd.sort_values(by='pop_density',ascending = False)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21476\1432811215.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   world_gfd['pop_density']= world_gfd.pop_est / world_gfd.area * 10**6
#          pop_est                continent                    name iso_a3  \
# 99   163046161.0                     Asia              Bangladesh    BGD
# 79     4685306.0                     Asia               Palestine    PSE
# 140   23568378.0                     Asia                  Taiwan    TWN
# 77     6855713.0                     Asia                 Lebanon    LBN
# 169   12626950.0                   Africa                  Rwanda    RWA
# ..           ...                      ...                     ...    ...
# 144     361313.0                   Europe                 Iceland    ISL
# 20        3398.0            South America            Falkland Is.    FLK
# ...

# %%
figsize =(20, 11)
world_gfd.plot('pop_density', legend=True, figsize=figsize)
# Out:
# <Axes: >

# %%
norm=matplotlib.colors.LogNorm(vmin=world_gfd.pop_density.min(),vmax=world_gfd.pop_density.max())
world_gfd.to_crs("epsg:4326").plot(column="pop_density",figsize=figsize, legend=True, norm=norm)
# Out:
# <Axes: >

# %%
deaths_df = gpd.read_file('SnowGIS\SnowGIS\Cholera_Deaths.shp')
pumps_df = gpd.read_file('SnowGIS\SnowGIS\Pumps.shp')

# %%
deaths_df.head()
# Out:
#    Id  Count                       geometry
# 0   0      3  POINT (529308.741 181031.352)
# 1   0      2  POINT (529312.164 181025.172)
# 2   0      1  POINT (529314.382 181020.294)
# 3   0      1  POINT (529317.380 181014.259)
# 4   0      4  POINT (529320.675 181007.872)

# %%
deaths_df.crs
# Out:
# <Projected CRS: EPSG:27700>
# Name: OSGB36 / British National Grid
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: United Kingdom (UK) - offshore to boundary of UKCS within 49°45'N to 61°N and 9°W to 2°E; onshore Great Britain (England, Wales and Scotland). Isle of Man onshore.
# - bounds: (-9.01, 49.75, 2.01, 61.01)
# Coordinate Operation:
# - name: British National Grid
# - method: Transverse Mercator
# Datum: Ordnance Survey of Great Britain 1936
# - Ellipsoid: Airy 1830
# - Prime Meridian: Greenwich

# %%
pumps_df.head()
# Out:
#    Id                       geometry
# 0   0  POINT (529396.539 181025.063)
# 1   0  POINT (529192.538 181079.391)
# 2   0  POINT (529183.740 181193.735)
# 3   0  POINT (529748.911 180924.207)
# 4   0  POINT (529613.205 180896.804)

# %%
pumps_df.crs
# Out:
# <Projected CRS: EPSG:27700>
# Name: OSGB36 / British National Grid
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: United Kingdom (UK) - offshore to boundary of UKCS within 49°45'N to 61°N and 9°W to 2°E; onshore Great Britain (England, Wales and Scotland). Isle of Man onshore.
# - bounds: (-9.01, 49.75, 2.01, 61.01)
# Coordinate Operation:
# - name: British National Grid
# - method: Transverse Mercator
# Datum: Ordnance Survey of Great Britain 1936
# - Ellipsoid: Airy 1830
# - Prime Meridian: Greenwich

# %%
ax = deaths_df.plot(column='Count', alpha=0.5, edgecolor='k', legend=True)

# %%
ax = deaths_df.plot(
 column="Count", figsize=(15, 15), alpha=0.5, edgecolor="k", legend=True
)
pumps_df.plot(ax=ax, marker="x", color="red", markersize=50)
# Out:
# <Axes: >

# %%
ax = deaths_df.plot(column="Count",figsize=(15,15) ,alpha=0.5, edgecolor="k", legend=True)
pumps_df.plot(ax=ax, marker='x', color='red', markersize=50)
ctx.add_basemap(
 ax,
 crs=deaths_df.crs.to_string()
)

# %%
ax = deaths_df.plot(
 column="Count", figsize=(15, 15), alpha=0.5, edgecolor="k", legend=True
)
pumps_df.plot(ax=ax, marker="x", color="red", markersize=50)
ctx.add_basemap(
 ax,
 crs=deaths_df.crs.to_string(),
 source="SnowGIS\SnowGIS\SnowMap.tif")
